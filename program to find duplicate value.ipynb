# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-lab-assignment/blob/main/program%20to%20find%20duplicate%20value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1, 2, 3, 2, 4, 5, 1]
duplicates = []

for i in lst:
    if lst.count(i) > 1 and i not in duplicates:
        duplicates.append(i)

print(duplicates)
# Out:
# [1, 2]
