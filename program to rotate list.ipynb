# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-lab-assignment/blob/main/program%20to%20rotate%20list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [10, 20, 30, 40, 50]
k = 2

k = k % len(lst)
rotated = lst[-k:] + lst[:-k]

print(rotated)
# Out:
# [40, 50, 10, 20, 30]
