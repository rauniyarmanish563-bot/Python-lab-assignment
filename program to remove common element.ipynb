# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-lab-assignment/blob/main/program%20to%20remove%20common%20element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to remove common elements
def remove_common(l1, l2):
    result = []
    for i in l1:
        if i not in l2:
            result.append(i)
    return result

# Main
print(remove_common([1,2,3,4], [3,4,5]))
# Out:
# [1, 2]
