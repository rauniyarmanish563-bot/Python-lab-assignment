# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-lab-assignment/blob/main/program%20to%20remove%20duplicates%20and%20convert%20to%20tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to remove duplicates and convert to tuple
def list_to_tuple(lst):
    return tuple(set(lst))

# Main
print(list_to_tuple([1,2,2,3,4,4]))
# Out:
# (1, 2, 3, 4)
